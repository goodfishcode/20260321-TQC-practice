# %% [markdown]
# # TQC+ 程式語言 Python 第7類：數組（Tuple）、集合（Set）、詞典（Dictionary）
#
# 來源：[doc/TQC_Python_701_710_tuple_set_dictionary.md](../doc/TQC_Python_701_710_tuple_set_dictionary.md)
#
# 使用方式：
# - 每題請實作 `solve_題號(input_data: str) -> str`
# - 完成後直接執行該題下方的測試 cell
# - 測試比對會保留空白與換行差異，只忽略最後多出的空白行

# %%
def normalize_output(text):
    if not isinstance(text, str):
        text = str(text)
    text = text.replace("\r\n", "\n")
    return text.rstrip("\n")


def run_example_tests(problem_code, func, cases):
    if not cases:
        print(f"{problem_code}: 找不到可自動解析的完整範例，請自行補測試。")
        return

    for idx, case in enumerate(cases, start=1):
        actual = normalize_output(func(case["input"]))
        expected = normalize_output(case["expected"])
        if actual != expected:
            raise AssertionError(
                f"[{problem_code} case {idx}]\n"
                f"input:\n{case['input']!r}\n\n"
                f"expected:\n{expected!r}\n\n"
                f"actual:\n{actual!r}"
            )

    print(f"{problem_code}: {len(cases)} 個範例測試通過。")

# %% [markdown]
# # 701 串列數組轉換
#
# ## 題目說明
#
# 請撰寫程式，將輸入的串列資料轉換為數組（Tuple）並輸出。
#
# ## 輸入說明
#
# 輸入一列整數（以空白分隔）。
#
# ## 輸出說明
#
# 將串列轉換為數組並輸出。
#
# ## 範例輸入
#
# ```
# 1 2 3 4 5
# ```
#
# ## 範例輸出
#
# ```
# (1, 2, 3, 4, 5)
# ```
#
# ---

# %%
def solve_701(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_701")

# %%
cases_701 = [
{
    'input': '1 2 3 4 5',
    'expected': '(1, 2, 3, 4, 5)',
}
]
run_example_tests("701", solve_701, cases_701)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_701(custom_input))

# %% [markdown]
# # 702 數組合併排序
#
# ## 題目說明
#
# 請撰寫程式，將兩個數組合併後進行排序並輸出。
#
# ## 輸入說明
#
# 輸入兩列整數。
#
# ## 輸出說明
#
# 將兩個數組合併後排序並輸出。
#
# ## 範例輸入
#
# ```
# 1 5 3
# 2 4 6
# ```
#
# ## 範例輸出
#
# ```
# 1 2 3 4 5 6
# ```
#
# ---

# %%
s1 = input()
s2 = input()
t1 = tuple(map(int, s1.split()))
t2 = tuple(map(int, s2.split()))
combine = t1+t2
print(f'Combined tuple before sorting: {combine}')

combine_ls = list(combine)
combine_sort = combine_ls.sort()
print(f'Combined list after sorting: {combine_sort}')
# Out:
# Combined tuple before sorting: (1, 5, 3, 2, 4, 6)
# Combined list after sorting: None

# %%
# 老師解答
data1 = []
data2 = []

print('Create tuple1:')
while True:
    num = int(input())
    if num == -9999:
        break
    data1.append(num)

print('Create tuple2:')
while True:
    num = int(input())
    if num == -9999:
        break
    data2.append(num)

tuple1 = tuple(data1)
tuple2 = tuple(data2)

combined_tuple = tuple1 + tuple2
sorted_list = sorted(combined_tuple)

print('Combined tuple before sorting:', combined_tuple)
print('Combined list after sorting:', sorted_list)
# Out:
# Create tuple1:
# Create tuple2:
# Combined tuple before sorting: (1, 5, 3, 2, 4, 6)
# Combined list after sorting: [1, 2, 3, 4, 5, 6]

# %%
def solve_702(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_702")

# %%
cases_702 = [
{
    'input': '1 5 3\n2 4 6',
    'expected': '1 2 3 4 5 6',
}
]
run_example_tests("702", solve_702, cases_702)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_702(custom_input))

# %% [markdown]
# # 703 數組條件判斷
#
# ## 題目說明
#
# 請撰寫程式，判斷數組中的元素是否符合指定條件。
#
# ## 輸入說明
#
# 輸入一列整數。
#
# ## 輸出說明
#
# 輸出符合條件的數值。
#
# ## 範例輸入
#
# ```
# 3 7 2 8 5
# ```
#
# ## 範例輸出
#
# ```
# 8
# ```
#
# ---

# %%
def solve_703(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_703")

# %%
cases_703 = [
{
    'input': '3 7 2 8 5',
    'expected': '8',
}
]
run_example_tests("703", solve_703, cases_703)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_703(custom_input))

# %% [markdown]
# # 704 集合條件判斷
#
# ## 題目說明
#
# 請撰寫程式判斷兩集合之間的關係。
#
# ## 輸入說明
#
# 輸入兩列整數，分別代表兩個集合。
#
# ## 輸出說明
#
# 輸出集合關係判斷結果。
#
# ## 範例輸入
#
# ```
# 1 2 3
# 2 3
# ```
#
# ## 範例輸出
#
# ```
# True
# ```
#
# ---

# %%
def solve_704(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_704")

# %%
cases_704 = [
{
    'input': '1 2 3\n2 3',
    'expected': 'True',
}
]
run_example_tests("704", solve_704, cases_704)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_704(custom_input))

# %% [markdown]
# # 705 子集合與超集合
#
# ## 題目說明
#
# 判斷兩個集合之間是否為子集合或超集合。
#
# ## 輸入說明
#
# 輸入兩列整數。
#
# ## 輸出說明
#
# 輸出是否為子集合或超集合。
#
# ## 範例輸入
#
# ```
# 1 2
# 1 2 3 4
# ```
#
# ## 範例輸出
#
# ```
# True
# ```
#
# ---

# %%
def solve_705(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_705")

# %%
cases_705 = [
{
    'input': '1 2\n1 2 3 4',
    'expected': 'True',
}
]
run_example_tests("705", solve_705, cases_705)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_705(custom_input))

# %% [markdown]
# # 706 全字母句
#
# ## 題目說明
#
# 請撰寫程式判斷輸入句子是否為全字母句（Pangram）。
#
# ## 輸入說明
#
# 輸入一行字串。
#
# ## 輸出說明
#
# 若為全字母句輸出 True，否則輸出 False。
#
# ## 範例輸入
#
# ```
# The quick brown fox jumps over the lazy dog
# ```
#
# ## 範例輸出
#
# ```
# True
# ```
#
# ---

# %%
def solve_706(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_706")

# %%
cases_706 = [
{
    'input': 'The quick brown fox jumps over the lazy dog',
    'expected': 'True',
}
]
run_example_tests("706", solve_706, cases_706)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_706(custom_input))

# %% [markdown]
# # 707 共同科目
#
# ## 題目說明
#
# 請撰寫程式找出兩組科目的共同元素。
#
# ## 輸入說明
#
# 輸入兩列科目名稱。
#
# ## 輸出說明
#
# 輸出兩組資料中的共同科目。
#
# ## 範例輸入
#
# ```
# Math English Science
# English History Math
# ```
#
# ## 範例輸出
#
# ```
# Math English
# ```
#
# ---

# %%
def solve_707(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_707")

# %%
cases_707 = [
{
    'input': 'Math English Science\nEnglish History Math',
    'expected': 'Math English',
}
]
run_example_tests("707", solve_707, cases_707)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_707(custom_input))

# %% [markdown]
# # 708 詞典合併
#
# ## 題目說明
#
# 請撰寫程式將兩個詞典合併並輸出。
#
# ## 輸入說明
#
# 輸入兩列 key:value 資料。
#
# ## 輸出說明
#
# 輸出合併後的詞典。
#
# ## 範例輸入
#
# ```
# a:1 b:2
# c:3 d:4
# ```
#
# ## 範例輸出
#
# ```
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}
# ```
#
# ---

# %%
def solve_708(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_708")

# %%
cases_708 = [
{
    'input': 'a:1 b:2\nc:3 d:4',
    'expected': "{'a': 1, 'b': 2, 'c': 3, 'd': 4}",
}
]
run_example_tests("708", solve_708, cases_708)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_708(custom_input))

# %% [markdown]
# # 709 詞典排序
#
# ## 題目說明
#
# 請撰寫程式將詞典依照 key 進行排序並輸出。
#
# ## 輸入說明
#
# 輸入多組 key:value。
#
# ## 輸出說明
#
# 依 key 排序後輸出詞典。
#
# ## 範例輸入
#
# ```
# b:2 a:1 c:3
# ```
#
# ## 範例輸出
#
# ```
# a:1
# b:2
# c:3
# ```
#
# ---

# %%
def solve_709(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_709")

# %%
cases_709 = [
{
    'input': 'b:2 a:1 c:3',
    'expected': 'a:1\nb:2\nc:3',
}
]
run_example_tests("709", solve_709, cases_709)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_709(custom_input))

# %% [markdown]
# # 710 詞典搜尋
#
# ## 題目說明
#
# 請撰寫程式依照 key 搜尋詞典中的值。
#
# ## 輸入說明
#
# 輸入詞典資料與查詢 key。
#
# ## 輸出說明
#
# 輸出對應的 value。
#
# ## 範例輸入
#
# ```
# a:1 b:2 c:3
# b
# ```
#
# ## 範例輸出
#
# ```
# 2
# ```

# %%
# 老師解答
items = {}

while True:
    key = input('Key: ')
    if key == 'end':
        break
    value = input('Value: ')
    items[key] = value

query = input('Search Key: ')
print(query in items)
# Out:
# True

# %%
def creat_dict(key, value):
    data = {}
    while key != 'end':
        key = input("Key: ")
        if key != 'end':
            value = input("Value: ")
            data[key] = value
        if key == 'end':
            return data
my_dict = creat_dict('key', 'value')
search_key = input("Search key: ")
if search_key in my_dict:
    print(True)
else:
    print(False)
# Out:
# False

# %%
def solve_710(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_710")

# %%
cases_710 = [
{
    'input': 'a:1 b:2 c:3\nb',
    'expected': '2',
}
]
run_example_tests("710", solve_710, cases_710)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_710(custom_input))
