# %% [markdown]
# # TQC+ 程式語言 Python 第9類：檔案與異常處理（901–910）
#
# 來源：[doc/TQC_Python_901_910_file_handling_exceptions.md](../doc/TQC_Python_901_910_file_handling_exceptions.md)
#
# 使用方式：
# - 每題請實作 `solve_題號(input_data: str) -> str`
# - 完成後直接執行該題下方的測試 cell
# - 測試比對會保留空白與換行差異，只忽略最後多出的空白行

# %%
def normalize_output(text):
    if not isinstance(text, str):
        text = str(text)
    text = text.replace("\r\n", "\n")
    return text.rstrip("\n")


def run_example_tests(problem_code, func, cases):
    if not cases:
        print(f"{problem_code}: 找不到可自動解析的完整範例，請自行補測試。")
        return

    for idx, case in enumerate(cases, start=1):
        actual = normalize_output(func(case["input"]))
        expected = normalize_output(case["expected"])
        if actual != expected:
            raise AssertionError(
                f"[{problem_code} case {idx}]\n"
                f"input:\n{case['input']!r}\n\n"
                f"expected:\n{expected!r}\n\n"
                f"actual:\n{actual!r}"
            )

    print(f"{problem_code}: {len(cases)} 個範例測試通過。")

# %% [markdown]
# # 901 成績資料
#
# ## 題目說明
#
# 請撰寫程式，將輸入的學生姓名與成績寫入檔案中，並輸出檔案內容。
#
# ## 輸入說明
#
# 輸入學生姓名與成績。
#
# ## 輸出說明
#
# 將資料寫入檔案並顯示檔案內容。
#
# ## 範例輸入
#
# ```
# John 80
# Mary 90
# ```
#
# ## 範例輸出
#
# ```
# John 80
# Mary 90
# ```
#
# ---

# %%
def solve_901(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_901")

# %%
cases_901 = [
{
    'input': 'John 80\nMary 90',
    'expected': 'John 80\nMary 90',
}
]
run_example_tests("901", solve_901, cases_901)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_901(custom_input))

# %% [markdown]
# # 902 資料加總
#
# ## 題目說明
#
# 請撰寫程式，讀取檔案中的數值並計算總和。
#
# ## 輸入說明
#
# 輸入數值資料並寫入檔案。
#
# ## 輸出說明
#
# 輸出所有數值的總和。
#
# ## 範例輸入
#
# ```
# 10
# 20
# 30
# ```
#
# ## 範例輸出
#
# ```
# 60
# ```
#
# ---

# %%
def solve_902(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_902")

# %%
cases_902 = [
{
    'input': '10\n20\n30',
    'expected': '60',
}
]
run_example_tests("902", solve_902, cases_902)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_902(custom_input))

# %% [markdown]
# # 903 成績資料
#
# ## 題目說明
#
# 請撰寫程式，從檔案讀取學生資料並顯示。
#
# ## 輸入說明
#
# 檔案中包含學生姓名與成績。
#
# ## 輸出說明
#
# 輸出學生姓名與成績。
#
# ## 範例輸入
#
# ```
# Amy 85
# Tom 92
# ```
#
# ## 範例輸出
#
# ```
# Amy 85
# Tom 92
# ```
#
# ---

# %%
def solve_903(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_903")

# %%
cases_903 = [
{
    'input': 'Amy 85\nTom 92',
    'expected': 'Amy 85\nTom 92',
}
]
run_example_tests("903", solve_903, cases_903)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_903(custom_input))

# %% [markdown]
# # 904 資料計算
#
# ## 題目說明
#
# 請撰寫程式，讀取檔案資料並計算平均值。
#
# ## 輸入說明
#
# 檔案包含多個數值。
#
# ## 輸出說明
#
# 輸出平均值。
#
# ## 範例輸入
#
# ```
# 10
# 20
# 30
# ```
#
# ## 範例輸出
#
# ```
# 20
# ```
#
# ---

# %%
def solve_904(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_904")

# %%
cases_904 = [
{
    'input': '10\n20\n30',
    'expected': '20',
}
]
run_example_tests("904", solve_904, cases_904)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_904(custom_input))

# %% [markdown]
# # 905 字串資料刪除
#
# ## 題目說明
#
# 請撰寫程式，讀取檔案內容並刪除指定字串。
#
# ## 輸入說明
#
# 輸入一段文字與要刪除的字串。
#
# ## 輸出說明
#
# 輸出刪除後的結果。
#
# ## 範例輸入
#
# ```
# hello world
# world
# ```
#
# ## 範例輸出
#
# ```
# hello
# ```
#
# ---

# %%
def solve_905(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_905")

# %%
cases_905 = [
{
    'input': 'hello world\nworld',
    'expected': 'hello',
}
]
run_example_tests("905", solve_905, cases_905)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_905(custom_input))

# %% [markdown]
# # 906 字串資料取代
#
# ## 題目說明
#
# 請撰寫程式，將檔案中的指定字串取代為新的字串。
#
# ## 輸入說明
#
# 輸入原始字串與替換字串。
#
# ## 輸出說明
#
# 輸出替換後的內容。
#
# ## 範例輸入
#
# ```
# hello world
# world python
# ```
#
# ## 範例輸出
#
# ```
# hello python
# ```
#
# ---

# %%
def solve_906(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_906")

# %%
cases_906 = [
{
    'input': 'hello world\nworld python',
    'expected': 'hello python',
}
]
run_example_tests("906", solve_906, cases_906)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_906(custom_input))

# %% [markdown]
# # 907 詳細資料顯示
#
# ## 題目說明
#
# 請撰寫程式，從檔案中讀取資料並顯示詳細內容。
#
# ## 輸入說明
#
# 檔案中包含多筆資料。
#
# ## 輸出說明
#
# 輸出檔案內容。
#
# ## 範例輸入
#
# ```
# Name: John
# Age: 20
# ```
#
# ## 範例輸出
#
# ```
# Name: John
# Age: 20
# ```
#
# ---

# %%
def solve_907(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_907")

# %%
cases_907 = [
{
    'input': 'Name: John\nAge: 20',
    'expected': 'Name: John\nAge: 20',
}
]
run_example_tests("907", solve_907, cases_907)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_907(custom_input))

# %% [markdown]
# # 908 單字次數計算
#
# ## 題目說明
#
# 請撰寫程式，讀取檔案並計算每個單字出現的次數。
#
# ## 輸入說明
#
# 輸入一段文字。
#
# ## 輸出說明
#
# 輸出每個單字的出現次數。
#
# ## 範例輸入
#
# ```
# apple banana apple
# ```
#
# ## 範例輸出
#
# ```
# apple 2
# banana 1
# ```
#
# ---

# %%
def solve_908(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_908")

# %%
cases_908 = [
{
    'input': 'apple banana apple',
    'expected': 'apple 2\nbanana 1',
}
]
run_example_tests("908", solve_908, cases_908)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_908(custom_input))

# %% [markdown]
# # 909 聯絡人資料
#
# ## 題目說明
#
# 請撰寫程式，建立聯絡人資料並儲存至檔案。
#
# ## 輸入說明
#
# 輸入姓名與電話。
#
# ## 輸出說明
#
# 輸出所有聯絡人資料。
#
# ## 範例輸入
#
# ```
# Tom 0912345678
# Amy 0987654321
# ```
#
# ## 範例輸出
#
# ```
# Tom 0912345678
# Amy 0987654321
# ```
#
# ---

# %%
def solve_909(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_909")

# %%
cases_909 = [
{
    'input': 'Tom 0912345678\nAmy 0987654321',
    'expected': 'Tom 0912345678\nAmy 0987654321',
}
]
run_example_tests("909", solve_909, cases_909)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_909(custom_input))

# %% [markdown]
# # 910 學生基本資料
#
# ## 題目說明
#
# 請撰寫程式，讀取學生基本資料並顯示。
#
# ## 輸入說明
#
# 檔案中包含學生姓名與學號。
#
# ## 輸出說明
#
# 輸出學生資料。
#
# ## 範例輸入
#
# ```
# John 12345
# Mary 67890
# ```
#
# ## 範例輸出
#
# ```
# John 12345
# Mary 67890
# ```
#
# ---

# %%
def solve_910(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_910")

# %%
cases_910 = [
{
    'input': 'John 12345\nMary 67890',
    'expected': 'John 12345\nMary 67890',
}
]
run_example_tests("910", solve_910, cases_910)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_910(custom_input))
