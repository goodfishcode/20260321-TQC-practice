# %% [markdown]
# # TQC+ 程式語言 Python 第8類：字串(String)的運作（801–810）
#
# 來源：[doc/TQC_Python_801_810_strings.md](../doc/TQC_Python_801_810_strings.md)
#
# 使用方式：
# - 每題請實作 `solve_題號(input_data: str) -> str`
# - 完成後直接執行該題下方的測試 cell
# - 測試比對會保留空白與換行差異，只忽略最後多出的空白行

# %%
def normalize_output(text):
    if not isinstance(text, str):
        text = str(text)
    text = text.replace("\r\n", "\n")
    return text.rstrip("\n")


def run_example_tests(problem_code, func, cases):
    if not cases:
        print(f"{problem_code}: 找不到可自動解析的完整範例，請自行補測試。")
        return

    for idx, case in enumerate(cases, start=1):
        actual = normalize_output(func(case["input"]))
        expected = normalize_output(case["expected"])
        if actual != expected:
            raise AssertionError(
                f"[{problem_code} case {idx}]\n"
                f"input:\n{case['input']!r}\n\n"
                f"expected:\n{expected!r}\n\n"
                f"actual:\n{actual!r}"
            )

    print(f"{problem_code}: {len(cases)} 個範例測試通過。")

# %% [markdown]
# # 801 字串索引
#
# ## 題目說明
#
# 請撰寫程式，輸入一個字串並輸出指定索引位置的字元。
#
# ## 輸入說明
#
# 輸入一個字串。
#
# ## 輸出說明
#
# 輸出指定索引位置的字元。
#
# ## 範例輸入
#
# ```
# Hello
# ```
#
# ## 範例輸出
#
# ```
# H
# ```
#
# ---

# %%
def solve_801(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_801")

# %%
cases_801 = [
{
    'input': 'Hello',
    'expected': 'H',
}
]
run_example_tests("801", solve_801, cases_801)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_801(custom_input))

# %% [markdown]
# # 802 字元對應
#
# ## 題目說明
#
# 請撰寫程式，依序輸出字串中每個字元與其索引位置。
#
# ## 輸入說明
#
# 輸入一個字串。
#
# ## 輸出說明
#
# 輸出字元與其索引。
#
# ## 範例輸入
#
# ```
# Python
# ```
#
# ## 範例輸出
#
# ```
# 0 P
# 1 y
# 2 t
# 3 h
# 4 o
# 5 n
# ```
#
# ---

# %%
def solve_802(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_802")

# %%
cases_802 = [
{
    'input': 'Python',
    'expected': '0 P\n1 y\n2 t\n3 h\n4 o\n5 n',
}
]
run_example_tests("802", solve_802, cases_802)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_802(custom_input))

# %% [markdown]
# # 803 倒數三個詞
#
# ## 題目說明
#
# 請撰寫程式，輸入一句話並輸出最後三個單字。
#
# ## 輸入說明
#
# 輸入一行字串。
#
# ## 輸出說明
#
# 輸出最後三個單字。
#
# ## 範例輸入
#
# ```
# Python is very powerful language
# ```
#
# ## 範例輸出
#
# ```
# very powerful language
# ```
#
# ---

# %%
def solve_803(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_803")

# %%
cases_803 = [
{
    'input': 'Python is very powerful language',
    'expected': 'very powerful language',
}
]
run_example_tests("803", solve_803, cases_803)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_803(custom_input))

# %% [markdown]
# # 804 大寫轉換
#
# ## 題目說明
#
# 請撰寫程式，將輸入字串轉換為大寫。
#
# ## 輸入說明
#
# 輸入一行字串。
#
# ## 輸出說明
#
# 輸出轉換為大寫的字串。
#
# ## 範例輸入
#
# ```
# hello python
# ```
#
# ## 範例輸出
#
# ```
# HELLO PYTHON
# ```
#
# ---

# %%
def solve_804(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_804")

# %%
cases_804 = [
{
    'input': 'hello python',
    'expected': 'HELLO PYTHON',
}
]
run_example_tests("804", solve_804, cases_804)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_804(custom_input))

# %% [markdown]
# # 805 字串輸出
#
# ## 題目說明
#
# 請撰寫程式，依指定格式輸出字串。
#
# ## 輸入說明
#
# 輸入一個字串。
#
# ## 輸出說明
#
# 依題目要求格式輸出。
#
# ## 範例輸入
#
# ```
# Python
# ```
#
# ## 範例輸出
#
# ```
# P y t h o n
# ```
#
# ---

# %%
def solve_805(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_805")

# %%
cases_805 = [
{
    'input': 'Python',
    'expected': 'P y t h o n',
}
]
run_example_tests("805", solve_805, cases_805)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_805(custom_input))

# %% [markdown]
# # 806 字元次數計算
#
# ## 題目說明
#
# 請撰寫程式，計算字串中指定字元出現的次數。
#
# ## 輸入說明
#
# 第一行輸入字串
# 第二行輸入要統計的字元
#
# ## 輸出說明
#
# 輸出該字元出現次數。
#
# ## 範例輸入
#
# ```
# banana
# a
# ```
#
# ## 範例輸出
#
# ```
# 3
# ```
#
# ---

# %%
def solve_806(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_806")

# %%
cases_806 = [
{
    'input': 'banana\na',
    'expected': '3',
}
]
run_example_tests("806", solve_806, cases_806)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_806(custom_input))

# %% [markdown]
# # 807 字串加總
#
# ## 題目說明
#
# 請撰寫程式，將字串中的數字相加。
#
# ## 輸入說明
#
# 輸入一個包含數字的字串。
#
# ## 輸出說明
#
# 輸出所有數字的總和。
#
# ## 範例輸入
#
# ```
# 12345
# ```
#
# ## 範例輸出
#
# ```
# 15
# ```
#
# ---

# %%
def solve_807(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_807")

# %%
cases_807 = [
{
    'input': '12345',
    'expected': '15',
}
]
run_example_tests("807", solve_807, cases_807)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_807(custom_input))

# %% [markdown]
# # 808 社會安全碼
#
# ## 題目說明
#
# 請撰寫程式，判斷輸入字串是否符合社會安全碼格式。
#
# ## 輸入說明
#
# 輸入一個字串。
#
# ## 輸出說明
#
# 若格式正確輸出 True，否則輸出 False。
#
# ## 範例輸入
#
# ```
# 123-45-6789
# ```
#
# ## 範例輸出
#
# ```
# True
# ```
#
# ---

# %%
def solve_808(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_808")

# %%
cases_808 = [
{
    'input': '123-45-6789',
    'expected': 'True',
}
]
run_example_tests("808", solve_808, cases_808)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_808(custom_input))

# %% [markdown]
# # 809 密碼規則
#
# ## 題目說明
#
# 請撰寫程式，檢查密碼是否符合規則：
#
# - 至少8個字元
# - 包含大寫字母
# - 包含小寫字母
# - 包含數字
#
# ## 輸入說明
#
# 輸入一個密碼字串。
#
# ## 輸出說明
#
# 符合規則輸出 True，否則 False。
#
# ## 範例輸入
#
# ```
# Abc12345
# ```
#
# ## 範例輸出
#
# ```
# True
# ```
#
# ---

# %%
def solve_809(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_809")

# %%
cases_809 = [
{
    'input': 'Abc12345',
    'expected': 'True',
}
]
run_example_tests("809", solve_809, cases_809)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_809(custom_input))

# %% [markdown]
# # 810 最大值與最小值之差
#
# ## 題目說明
#
# 請撰寫程式，找出字串中所有數字的最大值與最小值並計算差值。
#
# ## 輸入說明
#
# 輸入一個包含數字的字串。
#
# ## 輸出說明
#
# 輸出最大值與最小值的差。
#
# ## 範例輸入
#
# ```
# 59327
# ```
#
# ## 範例輸出
#
# ```
# 8
# ```
#
# ---

# %%
def solve_810(input_data: str) -> str:
    """讀入整份標準輸入字串，回傳整份標準輸出字串。"""
    raise NotImplementedError("Implement solve_810")

# %%
cases_810 = [
{
    'input': '59327',
    'expected': '8',
}
]
run_example_tests("810", solve_810, cases_810)

# %%
# 自訂測試區
# custom_input = """"""
# print(solve_810(custom_input))
